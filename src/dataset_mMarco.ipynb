# %%
import datasets
print(datasets.__version__)
# Out:
# 5.0.1

# %%
# Carrega a versão em português
dataset = load_dataset('unicamp-dl/mmarco', 'portuguese')
print(dataset['train'][0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Carrega a versão em português
# ----> 2 dataset = load_dataset('unicamp-dl/mmarco', 'portuguese')
#       3 print(dataset['train'][0])
#
# File d:\VsCode-Space\doc-ranker\venv\Lib\site-packages\datasets\load.py:1696, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1691 verification_mode = VerificationMode(
#    1692     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1693 )
#    1695 # Create a dataset builder
# -> 1696 builder_instance = load_dataset_builder(
#    1697     path=path,
#    1698     name=name,
#    1699     data_dir=data_dir,
# ...

# %%
# Carrega a versão em português
dataset = load_dataset('unicamp-dl/mmarco', 'english')
print(dataset['train'][0])
